# %%
import os
from tqdm.auto import tqdm
# %load_ext autoreload
# %autoreload 2
from helpers import get_df_from_logdir
import pandas as pd
import networkx as nx
import plotly.express as px
import numpy as np
import json
from matplotlib import pyplot as plt
from causal_util.helpers import unpickle

pd.set_option('display.max_columns', None)

# %%
# /home/sergei/ray_results/rl_const_sparsity_obs_space_env_sm5_linear_with_lagrange_dual_sparsity_gridsearch_eye_coeff
config_name = 'rl_const_sparsity_obs_space_env_sm5_linear_with_lagrange_dual_sparsity_per_component_gridsearch_eye_coeff'
path = f"/home/sergei/ray_results/{config_name}/"
trials = os.listdir(path)
trials = [os.path.join(path, trial) for trial in trials]
trials = sorted(filter(os.path.isdir, trials))
print(f"Got {len(trials)} trials")
# Out:
# Got 21 trials

# %% [markdown]
# # Reading trial data

# %%
def get_all_epochs(trial):
    try:
        df = get_df_from_logdir(trial, do_tqdm=False)
    except FileNotFoundError:
        return None
    except json.JSONDecodeError:
        return None
    
    return df

# %%
dfs = {trial: get_all_epochs(trial) for trial in tqdm(trials)}
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=21.0), HTML(value='')))

# %%
df = list(dfs.values())[0]

# %%
data = [df[~pd.isna(df.epochs)].iloc[-1] for df in dfs.values() if hasattr(df, 'epochs')]

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('sm5_linear_lagrange_per_component.csv', index=False)

# %%
df = pd.read_csv('sm5_linear_lagrange_per_component.csv')

# %%
list(df.columns)
# Out:
# ['epochs',
#  'n_samples',
#  'losses/opt1d/primal/coeff',
#  'losses/opt1d/primal/value',
#  'losses/opt1d/value',
#  'losses/opt2/dual/coeff',
#  'losses/opt2/dual/value',
#  'losses/opt2/value',
#  'grads/opt1d/grad_total_l1mean',
#  'grads/opt1d/grad_total_l2sum',
#  'grads/opt2/grad_total_l1mean',
#  'grads/opt2/grad_total_l2sum',
#  'metrics/batch_index',
#  'metrics/batch_size',
#  'metrics/primal/fit/value',
#  'metrics/primal/fit/coeff',
#  'metrics/primal/fit/mean_feature',
#  'metrics/primal/fit/std_feature',
#  'metrics/primal/fit/min_feature',
#  'metrics/primal/fit/max_feature',
#  'metrics/primal/fit/loss_fcons',
#  'metrics/primal/fit/loss_add',
#  'metrics/primal/fit/loss_rec',
#  'metrics/primal/fit/loss_fcons_pre',
#  'metrics/primal/fit/rec_fit_acc_loss_01_agg',
#  'metrics/primal/fit/loss_discrete',
#  'metrics/primal/fit/loss_orig',
#  'metrics/primal/fit/additional/value',
#  'metrics/primal/fit/obs/value',
#  'metrics/primal/fit/feat/value',
#  'metrics/primal/fit/feat_model/value',
#  'metrics/primal/fit/additional_orig/value',
#  'metrics/primal/fit/additional_orig/coeff',
#  'metrics/primal/fit/obs_orig/value',
#  'metrics/primal/fit/obs_orig/coeff',
#  'metrics/primal/fit/feat_orig/value',
#  'metrics/primal/fit/feat_orig/coeff',
#  'metrics/primal/fit/feat_model_orig/value',
#  'metrics/primal/fit/feat_model_orig/coeff',
#  'metrics/primal/fit_all_half/value',
#  'metrics/primal/fit_all_half/coeff',
#  'metrics/primal/fit_all_half/mean_feature',
#  'metrics/primal/fit_all_half/std_feature',
#  'metrics/primal/fit_all_half/min_feature',
#  'metrics/primal/fit_all_half/max_feature',
#  'metrics/primal/fit_all_half/loss_fcons',
#  'metrics/primal/fit_all_half/loss_add',
#  'metrics/primal/fit_all_half/loss_rec',
#  'metrics/primal/fit_all_half/loss_fcons_pre',
#  'metrics/primal/fit_all_half/rec_fit_acc_loss_01_agg',
#  'metrics/primal/fit_all_half/loss_discrete',
#  'metrics/primal/fit_all_half/loss_orig',
#  'metrics/primal/fit_all_half/additional/value',
#  'metrics/primal/fit_all_half/obs/value',
#  'metrics/primal/fit_all_half/feat/value',
#  'metrics/primal/fit_all_half/feat_model/value',
#  'metrics/primal/fit_all_half/additional_orig/value',
#  'metrics/primal/fit_all_half/additional_orig/coeff',
#  'metrics/primal/fit_all_half/obs_orig/value',
#  'metrics/primal/fit_all_half/obs_orig/coeff',
#  'metrics/primal/fit_all_half/feat_orig/value',
#  'metrics/primal/fit_all_half/feat_orig/coeff',
#  'metrics/primal/fit_all_half/feat_model_orig/value',
#  'metrics/primal/fit_all_half/feat_model_orig/coeff',
#  'metrics/primal/fit_all_on/value',
#  'metrics/primal/fit_all_on/coeff',
#  'metrics/primal/fit_all_on/mean_feature',
#  'metrics/primal/fit_all_on/std_feature',
#  'metrics/primal/fit_all_on/min_feature',
#  'metrics/primal/fit_all_on/max_feature',
#  'metrics/primal/fit_all_on/loss_fcons',
#  'metrics/primal/fit_all_on/loss_add',
#  'metrics/primal/fit_all_on/loss_rec',
#  'metrics/primal/fit_all_on/loss_fcons_pre',
#  'metrics/primal/fit_all_on/rec_fit_acc_loss_01_agg',
#  'metrics/primal/fit_all_on/loss_discrete',
#  'metrics/primal/fit_all_on/loss_orig',
#  'metrics/primal/fit_all_on/additional/value',
#  'metrics/primal/fit_all_on/obs/value',
#  'metrics/primal/fit_all_on/feat/value',
#  'metrics/primal/fit_all_on/feat_model/value',
#  'metrics/primal/fit_all_on/additional_orig/value',
#  'metrics/primal/fit_all_on/additional_orig/coeff',
#  'metrics/primal/fit_all_on/obs_orig/value',
#  'metrics/primal/fit_all_on/obs_orig/coeff',
#  'metrics/primal/fit_all_on/feat_orig/value',
#  'metrics/primal/fit_all_on/feat_orig/coeff',
#  'metrics/primal/fit_all_on/feat_model_orig/value',
#  'metrics/primal/fit_all_on/feat_model_orig/coeff',
#  'metrics/primal/reconstruction/value',
#  'metrics/primal/sparsity/sparsity_param_0_(11, 6)',
#  'metrics/primal/sparsity/value',
#  'metrics/primal/lagrange_multiplier/fit/additional',
#  'metrics/primal/lagrange_multiplier/fit/feat/0',
#  'metrics/primal/lagrange_multiplier/fit/feat/1',
#  'metrics/primal/lagrange_multiplier/fit/feat/2',
#  'metrics/primal/lagrange_multiplier/fit/feat/3',
#  'metrics/primal/lagrange_multiplier/fit/feat/4',
#  'metrics/primal/lagrange_multiplier/fit/feat/5',
#  'metrics/primal/lagrange_multiplier/fit/feat/hist',
#  'metrics/primal/lagrange_multiplier/fit/feat',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/0',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/1',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/2',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/3',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/4',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/5',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/hist',
#  'metrics/primal/lagrange_multiplier/fit/feat_model',
#  'metrics/primal/lagrange_multiplier/fit/obs/0',
#  'metrics/primal/lagrange_multiplier/fit/obs/1',
#  'metrics/primal/lagrange_multiplier/fit/obs/2',
#  'metrics/primal/lagrange_multiplier/fit/obs/3',
#  'metrics/primal/lagrange_multiplier/fit/obs/4',
#  'metrics/primal/lagrange_multiplier/fit/obs/hist',
#  'metrics/primal/lagrange_multiplier/fit/obs',
#  'metrics/primal/lagrange_multiplier/fit_all_on/additional',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/0',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/1',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/2',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/3',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/4',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/5',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/hist',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/0',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/1',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/2',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/3',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/4',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/5',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/hist',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/0',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/1',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/2',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/3',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/4',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/hist',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs',
#  'metrics/primal/lagrange_multiplier/reconstruction',
#  'metrics/primal/constraints_satisfied',
#  'metrics/primal/constraints_satisfied_frac',
#  'metrics/primal/constraint',
#  'metrics/primal/objective',
#  'metrics/primal/lagrangian',
#  'metrics/dual/fit/value',
#  'metrics/dual/fit/coeff',
#  'metrics/dual/fit/mean_feature',
#  'metrics/dual/fit/std_feature',
#  'metrics/dual/fit/min_feature',
#  'metrics/dual/fit/max_feature',
#  'metrics/dual/fit/loss_fcons',
#  'metrics/dual/fit/loss_add',
#  'metrics/dual/fit/loss_rec',
#  'metrics/dual/fit/loss_fcons_pre',
#  'metrics/dual/fit/rec_fit_acc_loss_01_agg',
#  'metrics/dual/fit/loss_discrete',
#  'metrics/dual/fit/loss_orig',
#  'metrics/dual/fit/additional/value',
#  'metrics/dual/fit/obs/value',
#  'metrics/dual/fit/feat/value',
#  'metrics/dual/fit/feat_model/value',
#  'metrics/dual/fit/additional_orig/value',
#  'metrics/dual/fit/additional_orig/coeff',
#  'metrics/dual/fit/obs_orig/value',
#  'metrics/dual/fit/obs_orig/coeff',
#  'metrics/dual/fit/feat_orig/value',
#  'metrics/dual/fit/feat_orig/coeff',
#  'metrics/dual/fit/feat_model_orig/value',
#  'metrics/dual/fit/feat_model_orig/coeff',
#  'metrics/dual/fit_all_half/value',
#  'metrics/dual/fit_all_half/coeff',
#  'metrics/dual/fit_all_half/mean_feature',
#  'metrics/dual/fit_all_half/std_feature',
#  'metrics/dual/fit_all_half/min_feature',
#  'metrics/dual/fit_all_half/max_feature',
#  'metrics/dual/fit_all_half/loss_fcons',
#  'metrics/dual/fit_all_half/loss_add',
#  'metrics/dual/fit_all_half/loss_rec',
#  'metrics/dual/fit_all_half/loss_fcons_pre',
#  'metrics/dual/fit_all_half/rec_fit_acc_loss_01_agg',
#  'metrics/dual/fit_all_half/loss_discrete',
#  'metrics/dual/fit_all_half/loss_orig',
#  'metrics/dual/fit_all_half/additional/value',
#  'metrics/dual/fit_all_half/obs/value',
#  'metrics/dual/fit_all_half/feat/value',
#  'metrics/dual/fit_all_half/feat_model/value',
#  'metrics/dual/fit_all_half/additional_orig/value',
#  'metrics/dual/fit_all_half/additional_orig/coeff',
#  'metrics/dual/fit_all_half/obs_orig/value',
#  'metrics/dual/fit_all_half/obs_orig/coeff',
#  'metrics/dual/fit_all_half/feat_orig/value',
#  'metrics/dual/fit_all_half/feat_orig/coeff',
#  'metrics/dual/fit_all_half/feat_model_orig/value',
#  'metrics/dual/fit_all_half/feat_model_orig/coeff',
#  'metrics/dual/fit_all_on/value',
#  'metrics/dual/fit_all_on/coeff',
#  'metrics/dual/fit_all_on/mean_feature',
#  'metrics/dual/fit_all_on/std_feature',
#  'metrics/dual/fit_all_on/min_feature',
#  'metrics/dual/fit_all_on/max_feature',
#  'metrics/dual/fit_all_on/loss_fcons',
#  'metrics/dual/fit_all_on/loss_add',
#  'metrics/dual/fit_all_on/loss_rec',
#  'metrics/dual/fit_all_on/loss_fcons_pre',
#  'metrics/dual/fit_all_on/rec_fit_acc_loss_01_agg',
#  'metrics/dual/fit_all_on/loss_discrete',
#  'metrics/dual/fit_all_on/loss_orig',
#  'metrics/dual/fit_all_on/additional/value',
#  'metrics/dual/fit_all_on/obs/value',
#  'metrics/dual/fit_all_on/feat/value',
#  'metrics/dual/fit_all_on/feat_model/value',
#  'metrics/dual/fit_all_on/additional_orig/value',
#  'metrics/dual/fit_all_on/additional_orig/coeff',
#  'metrics/dual/fit_all_on/obs_orig/value',
#  'metrics/dual/fit_all_on/obs_orig/coeff',
#  'metrics/dual/fit_all_on/feat_orig/value',
#  'metrics/dual/fit_all_on/feat_orig/coeff',
#  'metrics/dual/fit_all_on/feat_model_orig/value',
#  'metrics/dual/fit_all_on/feat_model_orig/coeff',
#  'metrics/dual/reconstruction/value',
#  'metrics/dual/sparsity/sparsity_param_0_(11, 6)',
#  'metrics/dual/sparsity/value',
#  'metrics/dual/lagrange_multiplier/fit/additional',
#  'metrics/dual/lagrange_multiplier/fit/feat/0',
#  'metrics/dual/lagrange_multiplier/fit/feat/1',
#  'metrics/dual/lagrange_multiplier/fit/feat/2',
#  'metrics/dual/lagrange_multiplier/fit/feat/3',
#  'metrics/dual/lagrange_multiplier/fit/feat/4',
#  'metrics/dual/lagrange_multiplier/fit/feat/5',
#  'metrics/dual/lagrange_multiplier/fit/feat/hist',
#  'metrics/dual/lagrange_multiplier/fit/feat',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/0',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/1',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/2',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/3',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/4',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/5',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/hist',
#  'metrics/dual/lagrange_multiplier/fit/feat_model',
#  'metrics/dual/lagrange_multiplier/fit/obs/0',
#  'metrics/dual/lagrange_multiplier/fit/obs/1',
#  'metrics/dual/lagrange_multiplier/fit/obs/2',
#  'metrics/dual/lagrange_multiplier/fit/obs/3',
#  'metrics/dual/lagrange_multiplier/fit/obs/4',
#  'metrics/dual/lagrange_multiplier/fit/obs/hist',
#  'metrics/dual/lagrange_multiplier/fit/obs',
#  'metrics/dual/lagrange_multiplier/fit_all_on/additional',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/0',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/1',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/2',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/3',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/4',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/5',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/hist',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/0',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/1',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/2',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/3',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/4',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/5',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/hist',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/0',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/1',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/2',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/3',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/4',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/hist',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs',
#  'metrics/dual/lagrange_multiplier/reconstruction',
#  'metrics/dual/constraints_satisfied',
#  'metrics/dual/constraints_satisfied_frac',
#  'metrics/dual/constraint',
#  'metrics/dual/objective',
#  'metrics/dual/lagrangian',
#  'metrics/cosine_to_true',
#  'metrics/episode_reward',
#  'metrics/fit_loss_smooth',
#  'metrics/graph_entropy_ma',
#  'metrics/graph_entropy_mf',
#  'metrics/max_element_ma',
#  'metrics/max_element_mf',
#  'metrics/nnz',
#  'metrics/non_sparse_fit_loss_smooth',
#  'metrics/threshold_action',
#  'metrics/threshold_annealer_threshold',
#  'metrics/threshold_features',
#  'metrics/|last_add_sparsity_gap',
#  'metrics/|last_mult_sparsity_gap',
#  'CausalModel',
#  'model',
#  'checkpoint_tune',
#  'checkpoint_size',
#  'time_this_iter_s',
#  'should_checkpoint',
#  'done',
#  'timesteps_total',
#  'episodes_total',
#  'training_iteration',
#  'experiment_id',
#  'date',
#  'timestamp',
#  'time_total_s',
#  'pid',
#  'hostname',
#  'node_ip',
#  'config/name',
#  'config/base_dir',
#  'config/db_name',
#  'config/sources',
#  'config/log_sys_usage',
#  'config/_gin__eyecoeff__loguniform',
#  'time_since_restore',
#  'timesteps_since_restore',
#  'iterations_since_restore',
#  'perf/cpu_util_percent',
#  'perf/ram_util_percent',
#  'perf/gpu_util_percent0',
#  'perf/vram_util_percent0',
#  'perf/gpu_util_percent1',
#  'perf/vram_util_percent1',
#  'trial_id',
#  'experiment_tag',
#  'metrics/primal/lagrange_multiplier/fit/feat/hist_mean',
#  'metrics/primal/lagrange_multiplier/fit/feat/hist_max',
#  'metrics/primal/lagrange_multiplier/fit/feat/hist_min',
#  'metrics/primal/lagrange_multiplier/fit/feat/hist_std',
#  'metrics/primal/lagrange_multiplier/fit/feat/hist_median',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/hist_mean',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/hist_max',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/hist_min',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/hist_std',
#  'metrics/primal/lagrange_multiplier/fit/feat_model/hist_median',
#  'metrics/primal/lagrange_multiplier/fit/obs/hist_mean',
#  'metrics/primal/lagrange_multiplier/fit/obs/hist_max',
#  'metrics/primal/lagrange_multiplier/fit/obs/hist_min',
#  'metrics/primal/lagrange_multiplier/fit/obs/hist_std',
#  'metrics/primal/lagrange_multiplier/fit/obs/hist_median',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/hist_mean',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/hist_max',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/hist_min',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/hist_std',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat/hist_median',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/hist_mean',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/hist_max',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/hist_min',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/hist_std',
#  'metrics/primal/lagrange_multiplier/fit_all_on/feat_model/hist_median',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/hist_mean',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/hist_max',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/hist_min',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/hist_std',
#  'metrics/primal/lagrange_multiplier/fit_all_on/obs/hist_median',
#  'metrics/dual/lagrange_multiplier/fit/feat/hist_mean',
#  'metrics/dual/lagrange_multiplier/fit/feat/hist_max',
#  'metrics/dual/lagrange_multiplier/fit/feat/hist_min',
#  'metrics/dual/lagrange_multiplier/fit/feat/hist_std',
#  'metrics/dual/lagrange_multiplier/fit/feat/hist_median',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/hist_mean',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/hist_max',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/hist_min',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/hist_std',
#  'metrics/dual/lagrange_multiplier/fit/feat_model/hist_median',
#  'metrics/dual/lagrange_multiplier/fit/obs/hist_mean',
#  'metrics/dual/lagrange_multiplier/fit/obs/hist_max',
#  'metrics/dual/lagrange_multiplier/fit/obs/hist_min',
#  'metrics/dual/lagrange_multiplier/fit/obs/hist_std',
#  'metrics/dual/lagrange_multiplier/fit/obs/hist_median',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/hist_mean',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/hist_max',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/hist_min',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/hist_std',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat/hist_median',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/hist_mean',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/hist_max',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/hist_min',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/hist_std',
#  'metrics/dual/lagrange_multiplier/fit_all_on/feat_model/hist_median',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/hist_mean',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/hist_max',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/hist_min',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/hist_std',
#  'metrics/dual/lagrange_multiplier/fit_all_on/obs/hist_median',
#  'metrics/context_stats_steps_collected',
#  'threshold_learner_action',
#  'metrics/context_stats_steps_sampled',
#  'metrics/context_stats_collect_iters',
#  'metrics/context_stats_collected_sampled_ratio',
#  'metrics/context_stats_pending_refs',
#  'metrics/context_stats_steps_collected_now',
#  'threshold_learner_feature',
#  'metrics/context_stats_steps_sampled_laps',
#  'metrics/context_stats_collect_time_s',
#  'metrics/context_stats_steps_collected_laps']

# %%
# plot_bar('epochs')
plt.rcParams.update({
    #'font.size': 8,
    'text.usetex': False,
#     'text.latex.preamble': r'\usepackage{amsfonts}',
    'font.family' : 'normal',
        'font.weight' : 'normal',
        'font.size'   : 20
})

# %%
plt.hist(df.epochs)
# Out:
# (array([8., 0., 2., 2., 1., 1., 0., 1., 0., 4.]),
#  array([    0. ,  2499.5,  4999. ,  7498.5,  9998. , 12497.5, 14997. ,
#         17496.5, 19996. , 22495.5, 24995. ]),
#  <BarContainer object of 10 artists>)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
plt.title("Sparsity w.r.t. $c_{eye}$")
plt.scatter(df['config/_gin__eyecoeff__loguniform'], df['metrics/nnz'])
plt.xscale('log')
plt.xlabel("$c_{eye}$")
plt.ylabel("Number of edges")
plt.axhline(15, ls='--')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
df_fine = df[df['metrics/nnz'] <= 20]

# %%
def find_trial(row, path=path):
    """Get folder name for a trial row."""
    trials = os.listdir(path)
    is_match = [row.trial_id in trial and row.experiment_tag in trial for trial in trials]
    assert sum(is_match) == 1
    idx = np.where(is_match)[0][0]
    trial = trials[idx]
    return trial

# %%
from path import Path
import gin
import sparse_causal_model_learner_rl.config
from causal_util import load_env, get_true_graph
gin.bind_parameter('Config._unpickle_skip_init', True)
gin.enter_interactive_mode()

# %%
trial_names = [find_trial(row) for _, row in df_fine.iterrows()]

# %%
gin.config_str()
# Out:
# '# Parameters for Config:\n# ==============================================================================\nConfig._unpickle_skip_init = True\n'

# %%
class model_():
    def __init__(self, Mf, Ma):
        self.Mf = Mf
        self.Ma = Ma
        
def adhoc_model(l):
    """Get an instance with Mf, Ma attributes."""
    n_f = l._unpickled_state['config'].get('feature_shape')[0]
    if gin.query_parameter('ModelDecoder.add_batch_number'):
        n_f += 1
    fadd = l._unpickled_state['config'].get('additional_feature_keys')
    print(n_f, fadd)
    
    gin.bind_parameter('graph_for_matrices.additional_features', fadd)
    gin.bind_parameter('plot_model.vmin', 0.0)
    gin.bind_parameter('plot_model.singlecolor_palette', True)
    gin.bind_parameter('plot_model.additional_features', fadd)
    P = l._unpickled_state['trainables_weights']['model']['model.switch.probas'].T
    
    print(P.shape)
    
    Mf = P[:, :n_f].detach().cpu().numpy()
    Ma = P[:, n_f:].detach().cpu().numpy()
    model = model_(Mf, Ma)
    return model

# %%
def model_from_trial(trial):
    trial_path = os.path.join(path, trial)
    checkpoints = [x for x in os.listdir(trial_path) if x.startswith('checkpoint')]
    checkpoint_epochs = {x: int(x.split('_')[1]) for x in checkpoints}
    checkpoints_rev = sorted(checkpoints, key=lambda x: checkpoint_epochs[x], reverse=True)
    
    l = None
    for checkpoint in checkpoints_rev:
        print("Trying checkpoint", checkpoint)
        try:
            ckpt_path = os.path.join(trial_path, checkpoint, 'checkpoint')
            l = unpickle(ckpt_path)
#             print(gin.config_str())
            break
        except Exception as e:
            print("Can't read", checkpoint)
            
    if l is None:
        raise ValueError("No checkpoints for trial", trial)
        
    gin.parse_config(l._unpickled_state['gin_config'])
    model = adhoc_model(l)
    
    return l, model

# %%
from itertools import permutations
from scipy.spatial.distance import cosine

# %%
def permute_model(m, perm, thr=0.9):
    permuted_Mf = m.Mf[perm, :][:, perm] > thr
    permuted_Ma = m.Ma[perm, :] > thr
    return permuted_Mf, permuted_Ma

def distance(m, m_true, perm, thr=0.9):
    permuted_Mf, permuted_Ma = permute_model(m, perm, thr=thr)
    Mf_true, Ma_true = m_true.Mf > thr, m_true.Ma > thr
    
    cosF = cosine(permuted_Mf.flatten(), Mf_true.flatten())
    cosA = cosine(permuted_Ma.flatten(), Ma_true.flatten())

    cos = cosF + cosA
    return cos

# %%
def check_last_feature(m, thr=0.9):
    Mf = m.Mf > 0.9
    Ma = m.Ma > 0.9
    assert np.sum(Mf[-1, :-1]) == 0
    assert np.sum(Mf[:-1, -1]) == 0
    assert Mf[-1, -1] == True, Mf[-1, -1]
    assert np.sum(Ma[-1, :]) == 0

# %%
def visualize_trial(trial):

    l, m = model_from_trial(trial)
    check_last_feature(m)

    env = load_env()
    G = get_true_graph(env)
    m_true = model_(G.As, G.Aa)

    fig = l.visualize_model(m)
    display(fig)
    gvz_m = l.visualize_graph(model=m)[1]
    gvz_m_true = l.visualize_graph(model=m_true)[1]
    
    display(gvz_m)
    
    n_f = m.Mf.shape[0]
    perms = list(permutations(range(n_f - 1)))

    distances = [distance(m, m_true, perm) for perm in perms]
    idx = np.argmin(distances)
    print("Best cosine", distances[idx])
    print("Best permutation", perms[idx])

    best_f, best_a = permute_model(m, perms[idx])
    display(l.visualize_graph(model=model_(1. * best_f, 1. * best_a))[1])
    return distances[idx]

# %%
cosines = []
for trial in trial_names:
    print(f"===== {trial} ======")
    dst = visualize_trial(trial)
    cosines.append(dst)
# Out:
# WARNING:root:Not performing initialization, only setting data. The object will not be valid
# ===== main_fcn_eb390_00000_0__gin__eyecoeff__loguniform=441.66_2021-04-15_11-49-49 ======
# Trying checkpoint checkpoint_8628
# 6 None
# torch.Size([6, 11])
# Make environment SparseMatrix-v0 [<class 'encoder.observation_encoder.LinearMatrixEncoder'>] {}
# Best cosine 0.0
# Best permutation (0, 3, 4, 1, 2)
# WARNING:root:Not performing initialization, only setting data. The object will not be valid
# ===== main_fcn_eb390_00004_4__gin__eyecoeff__loguniform=4.2376_2021-04-15_11-49-49 ======
# Trying checkpoint checkpoint_25000
# 6 None
# torch.Size([6, 11])
# Make environment SparseMatrix-v0 [<class 'encoder.observation_encoder.LinearMatrixEncoder'>] {}
# Best cosine 0.33184689521893906
# Best permutation (2, 1, 0, 4, 3)
# WARNING:root:Not performing initialization, only setting data. The object will not be valid
# ===== main_fcn_eb390_00005_5__gin__eyecoeff__loguniform=41.24_2021-04-15_22-17-46 ======
# Trying checkpoint checkpoint_5651
# 6 None
# torch.Size([6, 11])
# Make environment SparseMatrix-v0 [<class 'encoder.observation_encoder.LinearMatrixEncoder'>] {}
# Best cosine 0.0
# Best permutation (3, 2, 4, 1, 0)
# WARNING:root:Not performing initialization, only setting data. The object will not be valid
# ===== main_fcn_eb390_00006_6__gin__eyecoeff__loguniform=108.79_2021-04-15_22-17-46 ======
# Trying checkpoint checkpoint_6713
# 6 None
# torch.Size([6, 11])
# Make environment SparseMatrix-v0 [<class 'encoder.observation_encoder.LinearMatrixEncoder'>] {}
# Best cosine 0.0
# Best permutation (0, 3, 1, 2, 4)
# WARNING:root:Not performing initialization, only setting data. The object will not be valid
# ===== main_fcn_eb390_00007_7__gin__eyecoeff__loguniform=834.29_2021-04-15_22-38-57 ======
# Trying checkpoint checkpoint_18000
# 6 None
# torch.Size([6, 11])
# Make environment SparseMatrix-v0 [<class 'encoder.observation_encoder.LinearMatrixEncoder'>] {}
# Best cosine 0.33184689521893906
# Best permutation (3, 2, 4, 1, 0)

# %%
plt.hist(cosines)
# Out:
# (array([3., 0., 0., 0., 0., 0., 0., 0., 0., 2.]),
#  array([0.        , 0.03318469, 0.06636938, 0.09955407, 0.13273876,
#         0.16592345, 0.19910814, 0.23229283, 0.26547752, 0.29866221,
#         0.3318469 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df_fine['config/_gin__eyecoeff__loguniform'], cosines)#df['metrics/nnz']))
plt.xscale('log')

# %%
plt.scatter(df_fine['metrics/nnz'], cosines)

# %%
nx.draw(nx_m_true, pos = nx.spring_layout(nx_m_true))

# %%
from networkx.algorithms import isomorphism

# %%
match = isomorphism.GraphMatcher(nx_m, nx_m_true)

# %%
dir(match)
# Out:
# ['G1',
#  'G1_adj',
#  'G1_nodes',
#  'G2',
#  'G2_adj',
#  'G2_node_order',
#  'G2_nodes',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'candidate_pairs_iter',
#  'core_1',
#  'core_2',
#  'edge_match',
#  'initialize',
#  'inout_1',
#  'inout_2',
#  'is_isomorphic',
#  'isomorphisms_iter',
#  'mapping',
#  'match',
#  'node_match',
#  'old_recursion_limit',
#  'reset_recursion_limit',
#  'semantic_feasibility',
#  'state',
#  'subgraph_is_isomorphic',
#  'subgraph_is_monomorphic',
#  'subgraph_isomorphisms_iter',
#  'subgraph_monomorphisms_iter',
#  'syntactic_feasibility',
#  'test']

# %%
match.subgraph_is_isomorphic()
# Out:
# False
